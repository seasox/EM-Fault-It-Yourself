# %%
from glob import glob
import json
import matplotlib.pyplot as plt

# %%
files = sorted(glob("../dp_json/sk_2024-01-18*.json"))
files
# Out:
# ['../dp_json/sk_2024-01-18T11:23:27.939052.json',
#  '../dp_json/sk_2024-01-18T11:45:46.091176.json',
#  '../dp_json/sk_2024-01-18T12:08:43.117053.json',
#  '../dp_json/sk_2024-01-18T12:23:55.858274.json',
#  '../dp_json/sk_2024-01-18T12:35:59.317714.json',
#  '../dp_json/sk_2024-01-18T12:48:03.550385.json',
#  '../dp_json/sk_2024-01-18T13:00:07.575122.json',
#  '../dp_json/sk_2024-01-18T13:12:11.793517.json',
#  '../dp_json/sk_2024-01-18T13:24:15.757199.json',
#  '../dp_json/sk_2024-01-18T13:36:19.946373.json',
#  '../dp_json/sk_2024-01-18T13:48:23.932495.json',
#  '../dp_json/sk_2024-01-18T14:00:28.243858.json',
#  '../dp_json/sk_2024-01-18T14:12:32.427719.json',
#  '../dp_json/sk_2024-01-18T14:24:36.024220.json',
#  '../dp_json/sk_2024-01-18T14:36:39.539056.json',
#  '../dp_json/sk_2024-01-18T14:58:36.628423.json',
#  '../dp_json/sk_2024-01-18T15:10:20.063559.json',
#  '../dp_json/sk_2024-01-18T15:22:03.516454.json',
#  '../dp_json/sk_2024-01-18T15:36:59.346163.json',
#  '../dp_json/sk_2024-01-18T15:48:42.522761.json',
#  '../dp_json/sk_2024-01-18T16:00:25.353859.json',
#  '../dp_json/sk_2024-01-18T16:12:08.378509.json',
#  '../dp_json/sk_2024-01-18T16:23:51.830423.json',
#  '../dp_json/sk_2024-01-18T16:35:34.881811.json',
#  '../dp_json/sk_2024-01-18T16:47:17.782633(HW92).json',
#  '../dp_json/sk_2024-01-18T16:59:01.011259.json',
#  '../dp_json/sk_2024-01-18T17:10:44.249919.json',
#  '../dp_json/sk_2024-01-18T17:22:27.285382.json']

# %%
experiments = []
for file in files:
    with open(file, "r") as fp:
        d = json.load(fp)
        experiments.append(d)
        
experiments
# Out:
# [{'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 71,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 52,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': True,
#   'is_faulty': False,
#   'hw_h0': 71,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 82,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 71,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 63,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 71,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 70,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 70,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 80,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 71,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 61,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 71,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 62,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 63,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 81,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 67,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 71,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 69,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 58,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 53,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 72,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 75,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 64,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 92,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 89,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 72,
#   'register_key': '...',
#   'stack_key': '...'},
#  {'transmission_correct': False,
#   'is_faulty': False,
#   'hw_h0': 78,
#   'register_key': '...',
#   'stack_key': '...'}]
